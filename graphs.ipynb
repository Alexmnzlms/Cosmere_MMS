# %%
import pandas as pd
import plotnine as pn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("cosmere_gephi_v3.csv", index_col=0)

dataframe
# Out:
#             Label                book     planet     race region  \
# Id
# 1          Abaray  Stormlight Archive  Rosharans  Singers  Other
# 4          Abrial  Stormlight Archive  Rosharans    Veden  Other
# 5       Abrobadar  Stormlight Archive  Rosharans    Other  Other
# 6         Abronai  Stormlight Archive  Rosharans  Singers  Other
# 7            Abry  Stormlight Archive  Rosharans   Alethi  Other
# ...           ...                 ...        ...      ...    ...
# 1780       Zendid  Stormlight Archive  Rosharans    Other  Other
# 1781        Zetah  Stormlight Archive  Rosharans    Other  Other
# 1782  Zu (Roshar)  Stormlight Archive  Rosharans   Iriali  Other
# 1783     Zu (Sel)  The Emperor's Soul     Selish    Other  Other
# 1784         Zuln  Stormlight Archive  Rosharans  Singers  Other
#
#       componentnumber  Degree  Weighted Degree  Eccentricity  \
# Id
# 1                   0     137              174             4
# ...

# %%
print(dataframe[dataframe["Degree"] > 50]["Degree"].count() / dataframe["Degree"].count())

print(dataframe[dataframe["Weighted Degree"] > 50]["Weighted Degree"].count() / dataframe["Weighted Degree"].count())
# Out:
# 0.5705196182396607
# 0.5906680805938495

# %%
print(dataframe[dataframe["Degree"] > 100]["Degree"].count() / dataframe["Degree"].count())

print(dataframe[dataframe["Weighted Degree"] > 100]["Weighted Degree"].count() / dataframe["Weighted Degree"].count())
# Out:
# 0.256627783669141
# 0.30010604453870626

# %%
print(dataframe[dataframe["Degree"] > 200]["Degree"].count() / dataframe["Degree"].count())

print(dataframe[dataframe["Weighted Degree"] > 200]["Weighted Degree"].count() / dataframe["Weighted Degree"].count())
# Out:
# 0.010604453870625663
# 0.05408271474019088

# %%
graph = pn.ggplot(dataframe, pn.aes(x = "Degree"))
graph += pn.geom_density()
graph += pn.labs(
    title = "Densidad de Grado",
    y = "P(k)", 
    x = "k"
)
graph.save("memoria/img/densidad_grado.png")

print(graph)

graph = pn.ggplot(dataframe, pn.aes(x = "Degree"))
graph += pn.geom_density()
graph += pn.scale_y_log10()
graph += pn.scale_x_log10()
graph += pn.labs(
    title = "Densidad de Grado (Escala logaritmica)",
    y = "P(k)", 
    x = "k"
)
graph.save("memoria/img/densidad_grado_log.png")

print(graph)
# Out:
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/densidad_grado.png
# /tmp/ipykernel_7459/603324779.py:10: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/densidad_grado_log.png
# /tmp/ipykernel_7459/603324779.py:23: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().

# %%
graph = pn.ggplot(dataframe, pn.aes(x = "Weighted Degree"))
graph += pn.geom_density()
graph += pn.labs(
    title = "Densidad de Grado con Pesos",
    y = "P(k)", 
    x = "k"
)
graph.save("memoria/img/densidad_grado_pesos.png")

print(graph)

graph = pn.ggplot(dataframe, pn.aes(x = "Weighted Degree"))
graph += pn.scale_y_log10()
graph += pn.scale_x_log10()
graph += pn.geom_density()
graph += pn.labs(
    title = "Densidad de Grado con Pesos (Escala logaritmica)",
    y = "P(k)", 
    x = "k"
)
graph.save("memoria/img/densidad_grado_pesos_log.png")

print(graph)
# Out:
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/densidad_grado_pesos.png
# /tmp/ipykernel_7459/2119342487.py:10: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/densidad_grado_pesos_log.png
# /tmp/ipykernel_7459/2119342487.py:23: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().

# %%
graph = pn.ggplot(dataframe, pn.aes(x = "clustering"))
graph += pn.geom_histogram(binwidth=0.05)
graph += pn.labs(
    title = "Distribución del coeficiente de clustering C",
    x = "C de clustering", 
    y = "Nº de nodos"
)
graph.save("memoria/img/distribucion_clustering.png")

print(graph)
# Out:
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/distribucion_clustering.png
# /tmp/ipykernel_7459/777885596.py:10: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().

# %%
graph = pn.ggplot(dataframe, pn.aes(x = "clustering", y="Degree"))
graph += pn.geom_point()
graph += pn.labs(
    title = "Grado k vs coeficiente de clustering C",
    x = "k", 
    y = "C"
)
graph.save("memoria/img/grado_vs_clustering.png")

print(graph)
# Out:
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/grado_vs_clustering.png
# /tmp/ipykernel_7459/3561595477.py:10: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().

# %%
dataframe
# Out:
#             Label                book     planet     race region  \
# Id
# 1          Abaray  Stormlight Archive  Rosharans  Singers  Other
# 4          Abrial  Stormlight Archive  Rosharans    Veden  Other
# 5       Abrobadar  Stormlight Archive  Rosharans    Other  Other
# 6         Abronai  Stormlight Archive  Rosharans  Singers  Other
# 7            Abry  Stormlight Archive  Rosharans   Alethi  Other
# ...           ...                 ...        ...      ...    ...
# 1780       Zendid  Stormlight Archive  Rosharans    Other  Other
# 1781        Zetah  Stormlight Archive  Rosharans    Other  Other
# 1782  Zu (Roshar)  Stormlight Archive  Rosharans   Iriali  Other
# 1783     Zu (Sel)  The Emperor's Soul     Selish    Other  Other
# 1784         Zuln  Stormlight Archive  Rosharans  Singers  Other
#
#       componentnumber  Degree  Weighted Degree  Eccentricity  \
# Id
# 1                   0     137              174             4
# ...

# %%
dataframe["componentnumber"].value_counts()
# Out:
# componentnumber
# 0    909
# 2     11
# 3      7
# 1      4
# 5      3
# 7      3
# 4      2
# 6      2
# 8      2
# Name: count, dtype: int64

# %%
graph = pn.ggplot(dataframe, pn.aes(x = "Degree"))
graph += pn.geom_histogram()
graph += pn.labs(
    title = "Histograma del grado de los nodos",
    y = "Nº de nodos", 
    x = "Grado"
)
graph.save("memoria/img/histograma_grado.png")

graph.show()

graph = pn.ggplot(dataframe, pn.aes(x = "Weighted Degree"))
graph += pn.geom_histogram()
graph += pn.labs(
    title = "Histograma del grado (con peso) de los nodos",
    y = "Nº de nodos", 
    x = "Grado con peso"
)
graph.save("memoria/img/histograma_grado_peso.png")

graph.show()

graph = pn.ggplot(dataframe, pn.aes(x = "closnesscentrality"))
graph += pn.geom_histogram(binwidth=1e-2)
graph += pn.labs(
    title = "Histograma de la cercania de los nodos",
    y = "Nº de nodos", 
    x = "Cercania"
)
graph.save("memoria/img/histograma_cercania.png")

graph.show()

graph = pn.ggplot(dataframe, pn.aes(x = "betweenesscentrality"))
graph += pn.geom_histogram(bins=100)
graph += pn.labs(
    title = "Histograma de la intermediación de los nodos",
    y = "Nº de nodos", 
    x = "Intermediación"
)
graph.save("memoria/img/histograma_intermediacion.png")

graph.show()

graph = pn.ggplot(dataframe, pn.aes(x = "eigencentrality"))
graph += pn.geom_histogram(binwidth=1e-2)
graph += pn.labs(
    title = "Histograma del valor del vector propio de los nodos",
    y = "Nº de nodos", 
    x = "Valor del vector propio"
)
graph.save("memoria/img/histograma_vectorpropio.png")

graph.show()
# Out:
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/histograma_grado.png
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 18'. Pick better value with 'binwidth'.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 18'. Pick better value with 'binwidth'.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/manza/python-env/MMS/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: memoria/img/histograma_grado_peso.png
# ...
